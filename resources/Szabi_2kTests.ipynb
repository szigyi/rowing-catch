# %%
import sys
print(sys.executable)
# install into the kernel
# python -m pip install pandas
# python -m pip install -U matplotlib
# python -m pip install scipy
# python -m pip install seaborn
# Out:
# /usr/local/opt/python@3.11/bin/python3.11

# %%
import lib_2k
from lib_2k import Test2KData
import scipy
from scipy import stats
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(rc={'figure.figsize': (18, 8)})

# %%
source = [
    Test2KData('Szabi/2019.12.07.LogBook_PM5_Szabi_2k.csv', '2019.12.07', 3),
    Test2KData('Szabi/2024.03.05.LogBook_PM5_Szabi_2k.csv', '2024.03.05', 3),
    Test2KData('Szabi/2019.12.07.LogBook_PM5_Szabi_2k.csv', '2024.03.15', 3)
]

# %%
df = lib_2k.read_2k_split_results(source)

# %%
lib_2k.plot_2k_split_results('Szabi - 2k Split Results', df)

# %%
d = lib_2k.read_2k_total_results(source)

# %%
lib_2k.plot_2k_total_results('Szabi - 2K Total Results', d)
